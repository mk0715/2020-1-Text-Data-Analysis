# %%
import pandas as pd

# %% [markdown]
# - 선관위에서 제공하는 파일 다운받아서 열기

# %%
vote = pd.read_excel('투표율.xlsx')
vote
# Out:
#    중앙선거관리위원회 선거통계시스템               Unnamed: 1                Unnamed: 2  \
# 0           투표율 변동추이                      NaN                       NaN
# 1                NaN                      NaN                       NaN
# 2                시도명  5회 동시지방선거\n(2010.06.02)  19대 국회의원선거\n(2012.04.11)
# 3                 합계                     54.5                      54.2
# 4              서울특별시                     53.9                      55.5
# 5              부산광역시                     49.5                      54.6
# 6              대구광역시                     45.9                      52.3
# 7              인천광역시                     50.9                      51.4
# 8              광주광역시                     49.8                      52.7
# 9              대전광역시                     52.9                      54.2
# 10             울산광역시                     55.1                      55.7
# 11           세종특별자치시                      0.0                      59.2
# ...

# %%
vote = vote.iloc[2:]
vote
# Out:
#    중앙선거관리위원회 선거통계시스템               Unnamed: 1                Unnamed: 2  \
# 2                시도명  5회 동시지방선거\n(2010.06.02)  19대 국회의원선거\n(2012.04.11)
# 3                 합계                     54.5                      54.2
# 4              서울특별시                     53.9                      55.5
# 5              부산광역시                     49.5                      54.6
# 6              대구광역시                     45.9                      52.3
# 7              인천광역시                     50.9                      51.4
# 8              광주광역시                     49.8                      52.7
# 9              대전광역시                     52.9                      54.2
# 10             울산광역시                     55.1                      55.7
# 11           세종특별자치시                      0.0                      59.2
# 12               경기도                     51.8                      52.6
# 13               강원도                     62.3                      55.7
# ...

# %%
vote = vote.drop(vote.columns[[4,9]], axis='columns')
vote
# Out:
#    중앙선거관리위원회 선거통계시스템               Unnamed: 1                Unnamed: 2  \
# 2                시도명  5회 동시지방선거\n(2010.06.02)  19대 국회의원선거\n(2012.04.11)
# 3                 합계                     54.5                      54.2
# 4              서울특별시                     53.9                      55.5
# 5              부산광역시                     49.5                      54.6
# 6              대구광역시                     45.9                      52.3
# 7              인천광역시                     50.9                      51.4
# 8              광주광역시                     49.8                      52.7
# 9              대전광역시                     52.9                      54.2
# 10             울산광역시                     55.1                      55.7
# 11           세종특별자치시                      0.0                      59.2
# 12               경기도                     51.8                      52.6
# 13               강원도                     62.3                      55.7
# ...

# %%
vote.iloc[0]
# Out:
# 중앙선거관리위원회 선거통계시스템                         시도명
# Unnamed: 1            5회 동시지방선거\n(2010.06.02)
# Unnamed: 2           19대 국회의원선거\n(2012.04.11)
# Unnamed: 3            18대 대통령선거\n(2012.12.19)
# Unnamed: 5            6회 동시지방선거\n(2014.06.04)
# Unnamed: 6           20대 국회의원선거\n(2016.04.13)
# Unnamed: 7            19대 대통령선거\n(2017.05.09)
# Unnamed: 8            7회 동시지방선거\n(2018.06.13)
# Name: 2, dtype: object

# %%
vote.rename(columns=vote.iloc[0], inplace=True)

# %%
vote = vote[1:]
vote
# Out:
#         시도명 5회 동시지방선거\n(2010.06.02) 19대 국회의원선거\n(2012.04.11)  \
# 3        합계                    54.5                     54.2
# 4     서울특별시                    53.9                     55.5
# 5     부산광역시                    49.5                     54.6
# 6     대구광역시                    45.9                     52.3
# 7     인천광역시                    50.9                     51.4
# 8     광주광역시                    49.8                     52.7
# 9     대전광역시                    52.9                     54.2
# 10    울산광역시                    55.1                     55.7
# 11  세종특별자치시                     0.0                     59.2
# 12      경기도                    51.8                     52.6
# 13      강원도                    62.3                     55.7
# 14     충청북도                    58.8                     54.6
# 15     충청남도                    56.5                     52.4
# 16     전라북도                    59.3                     53.6
# ...

# %%
vote = vote.iloc[:1]
vote
# Out:
#   시도명 5회 동시지방선거\n(2010.06.02) 19대 국회의원선거\n(2012.04.11)  \
# 3  합계                    54.5                     54.2
#
#   18대 대통령선거\n(2012.12.19) 6회 동시지방선거\n(2014.06.04) 20대 국회의원선거\n(2016.04.13)  \
# 3                    75.8                    56.8                     58.0
#
#   19대 대통령선거\n(2017.05.09) 7회 동시지방선거\n(2018.06.13)
# 3                    77.2                    60.2

# %%
vote1 = vote.iloc[:,[3,6]]
vote1
# Out:
#   18대 대통령선거\n(2012.12.19) 19대 대통령선거\n(2017.05.09)
# 3                    75.8                    77.2

# %%
vote2 = vote.iloc[:,[2,5]]
vote2
# Out:
#   19대 국회의원선거\n(2012.04.11) 20대 국회의원선거\n(2016.04.13)
# 3                     54.2                     58.0

# %%
vote3 = vote.iloc[:,[1,4,7]]
vote3
# Out:
#   5회 동시지방선거\n(2010.06.02) 6회 동시지방선거\n(2014.06.04) 7회 동시지방선거\n(2018.06.13)
# 3                    54.5                    56.8                    60.2

# %%
vote.to_excel('투표율 수정.xlsx')
